# %%
import pandas as pd
ds=pd.read_csv("test.csv")
# sheet_data.head(10)
ds.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print(ds.columns)
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(pd.Categorical(ds["Cabin"]))
# Out:
# [NaN, NaN, NaN, NaN, NaN, ..., NaN, 'C105', NaN, NaN, NaN]
# Length: 418
# Categories (76, object): ['A11', 'A18', 'A21', 'A29', ..., 'F2', 'F33', 'F4', 'G6']

# %%
ds['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %%
ds.head(20)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %%
ds[5:35:4]
# Out:
#     PassengerId  Pclass                                               Name  \
# 5           897       3                         Svensson, Mr. Johan Cervin
# 9           901       3                            Davies, Mr. John Samuel
# 13          905       2                               Howard, Mr. Benjamin
# 17          909       3                                  Assaf, Mr. Gerios
# 21          913       3                          Olsen, Master. Artur Karl
# 25          917       3                            Robins, Mr. Alexander A
# 29          921       3                                  Samaan, Mr. Elias
# 33          925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
#
#        Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 5     male  14.0      0      0        7538   9.2250   NaN        S
# 9     male  21.0      2      0   A/4 48871  24.1500   NaN        S
# 13    male  63.0      1      0       24065  26.0000   NaN        S
# ...

# %%
ds.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
ds[["Name","Age"]][ds['Fare'] > 35.627188]
# Out:
#                                                   Name   Age
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  23.0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  47.0
# 20                              Rothschild, Mr. Martin  55.0
# 23                     Williams, Mr. Richard Norris II  21.0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  48.0
# ..                                                 ...   ...
# 402                     Gibson, Miss. Dorothy Winifred  22.0
# 403                             Carrau, Mr. Jose Pedro  17.0
# 407                         Widener, Mr. George Dunton  50.0
# 411    Minahan, Mrs. William Edward (Lillian E Thorpe)  37.0
# 414                       Oliva y Ocana, Dona. Fermina  39.0
#
# [97 rows x 2 columns]

# %%
female_class1=ds[['Name']][(ds["Sex"] == "female") & (ds["Pclass"]== 1)]
len(female_class1)
# Out:
# 50

# %%
ds[0:5]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked   time
# 0  34.5      0      0   330911   7.8292   NaN        Q  00:00
# 1  47.0      1      0   363272   7.0000   NaN        S  00:00
# 2  62.0      0      0   240276   9.6875   NaN        Q  00:00
# 3  27.0      0      0   315154   8.6625   NaN        S  00:00
# 4  22.0      1      1  3101298  12.2875   NaN        S  00:00

# %%
list[ds['Name',=False]]
# Out:
#   Cell In[44], line 1
#     list[ds['Name' index=False]]
#             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
